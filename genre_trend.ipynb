# %%
import pandas as pd
import json
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import itertools

# %%
path_in_str = 'data/anime_list_final_231.json'
json_file = open(path_in_str)
data = json.load(json_file)
df = pd.DataFrame.from_dict(data, orient='index')
df.columns
# Out:
# Index(['id', 'title', 'main_picture', 'alternative_titles', 'start_date',
#        'end_date', 'synopsis', 'mean', 'rank', 'popularity', 'num_list_users',
#        'num_scoring_users', 'nsfw', 'created_at', 'updated_at', 'media_type',
#        'status', 'genres', 'num_episodes', 'start_season', 'broadcast',
#        'source', 'average_episode_duration', 'rating', 'pictures',
#        'background', 'related_anime', 'related_manga', 'recommendations',
#        'studios', 'statistics', 'message', 'error'],
#       dtype='object')

# %%
df1 = pd.DataFrame(columns=df.columns)
df1 = df1[df1['genres'].notna()]
# df1 = df1[~df1['genres']]
# df1.dropna(subset=['genres'])
for count, row in df.iterrows():
    temp = row['genres']
    if not isinstance(temp, list):
        # print(type(temp))
        # print(type(temp))
        continue
    r1 = row
    for x in range(int(len(temp))):
        r1['genres'] = temp[x]
        df1.loc[len(df1.index)] = r1
df1
# Out:
#             id                       title  \
# 0          1.0                Cowboy Bebop
# 1          1.0                Cowboy Bebop
# 2          1.0                Cowboy Bebop
# 3          1.0                Cowboy Bebop
# 4          1.0                Cowboy Bebop
# ...        ...                         ...
# 58990  50216.0  Nani Yatte mo Umaku Ikanai
# 58991  50218.0                 Makafushigi
# 58992  50221.0                  Shine Post
# 58993  50221.0                  Shine Post
# 58994  50227.0                        Love
#
#                                             main_picture  \
# 0      {'medium': 'https://api-cdn.myanimelist.net/im...
# 1      {'medium': 'https://api-cdn.myanimelist.net/im...
# 2      {'medium': 'https://api-cdn.myanimelist.net/im...
# 3      {'medium': 'https://api-cdn.myanimelist.net/im...
# 4      {'medium': 'https://api-cdn.myanimelist.net/im...
# ...                                                  ...
# 58990  {'medium': 'https://api-cdn.myanimelist.net/im...
# 58991  {'medium': 'https://api-cdn.myanimelist.net/im...
# 58992  {'medium': 'https://api-cdn.myanimelist.net/im...
# 58993  {'medium': 'https://api-cdn.myanimelist.net/im...
# 58994  {'medium': 'https://api-cdn.myanimelist.net/im...
#
#                                       alternative_titles  start_date  \
# 0      {'synonyms': [], 'en': 'Cowboy Bebop', 'ja': '...  1998-04-03
# 1      {'synonyms': [], 'en': 'Cowboy Bebop', 'ja': '...  1998-04-03
# 2      {'synonyms': [], 'en': 'Cowboy Bebop', 'ja': '...  1998-04-03
# 3      {'synonyms': [], 'en': 'Cowboy Bebop', 'ja': '...  1998-04-03
# 4      {'synonyms': [], 'en': 'Cowboy Bebop', 'ja': '...  1998-04-03
# ...                                                  ...         ...
# 58990  {'synonyms': [], 'en': 'Nothing's Working Out'...  2021-09-26
# 58991  {'synonyms': ['MAKAFUKA'], 'en': '', 'ja': '摩訶...  2021-10-25
# 58992        {'synonyms': [], 'en': '', 'ja': 'シャインポスト'}     2022-07
# 58993        {'synonyms': [], 'en': '', 'ja': 'シャインポスト'}     2022-07
# 58994             {'synonyms': [], 'en': '', 'ja': 'ラヴ'}  2020-07-09
#
#          end_date                                           synopsis  mean  \
# 0      1999-04-24  In the year 2071, humanity has colonized sever...  8.77
# 1      1999-04-24  In the year 2071, humanity has colonized sever...  8.77
# 2      1999-04-24  In the year 2071, humanity has colonized sever...  8.77
# 3      1999-04-24  In the year 2071, humanity has colonized sever...  8.77
# 4      1999-04-24  In the year 2071, humanity has colonized sever...  8.77
# ...           ...                                                ...   ...
# 58990  2021-09-26                                                      NaN
# 58991  2021-10-25  Special animation for the collaboration betwee...   NaN
# 58992         NaN                                                      NaN
# 58993         NaN                                                      NaN
# 58994  2020-07-09                                                      NaN
#
#           rank  popularity  ...  rating  \
# 0         33.0        45.0  ...       r
# 1         33.0        45.0  ...       r
# 2         33.0        45.0  ...       r
# 3         33.0        45.0  ...       r
# 4         33.0        45.0  ...       r
# ...        ...         ...  ...     ...
# 58990      0.0         0.0  ...     NaN
# 58991  17161.0     18109.0  ...       g
# 58992      NaN     16301.0  ...     NaN
# 58993      NaN     16301.0  ...     NaN
# 58994      0.0         0.0  ...   pg_13
#
#                                                 pictures  \
# 0      [{'medium': 'https://api-cdn.myanimelist.net/i...
# 1      [{'medium': 'https://api-cdn.myanimelist.net/i...
# 2      [{'medium': 'https://api-cdn.myanimelist.net/i...
# 3      [{'medium': 'https://api-cdn.myanimelist.net/i...
# 4      [{'medium': 'https://api-cdn.myanimelist.net/i...
# ...                                                  ...
# 58990  [{'medium': 'https://api-cdn.myanimelist.net/i...
# 58991  [{'medium': 'https://api-cdn.myanimelist.net/i...
# 58992  [{'medium': 'https://api-cdn.myanimelist.net/i...
# 58993  [{'medium': 'https://api-cdn.myanimelist.net/i...
# 58994  [{'medium': 'https://api-cdn.myanimelist.net/i...
#
#                                               background  \
# 0      When Cowboy Bebop first aired in spring of 199...
# 1      When Cowboy Bebop first aired in spring of 199...
# 2      When Cowboy Bebop first aired in spring of 199...
# 3      When Cowboy Bebop first aired in spring of 199...
# 4      When Cowboy Bebop first aired in spring of 199...
# ...                                                  ...
# 58990
# 58991
# 58992  Shine Post is part of a multimedia project whi...
# 58993  Shine Post is part of a multimedia project whi...
# 58994
#
#                                            related_anime related_manga  \
# 0      [{'node': {'id': 5, 'title': 'Cowboy Bebop: Te...            []
# 1      [{'node': {'id': 5, 'title': 'Cowboy Bebop: Te...            []
# 2      [{'node': {'id': 5, 'title': 'Cowboy Bebop: Te...            []
# 3      [{'node': {'id': 5, 'title': 'Cowboy Bebop: Te...            []
# 4      [{'node': {'id': 5, 'title': 'Cowboy Bebop: Te...            []
# ...                                                  ...           ...
# 58990                                                 []            []
# 58991                                                 []            []
# 58992                                                 []            []
# 58993                                                 []            []
# 58994                                                 []            []
#
#                                          recommendations  \
# 0      [{'node': {'id': 205, 'title': 'Samurai Champl...
# 1      [{'node': {'id': 205, 'title': 'Samurai Champl...
# 2      [{'node': {'id': 205, 'title': 'Samurai Champl...
# 3      [{'node': {'id': 205, 'title': 'Samurai Champl...
# 4      [{'node': {'id': 205, 'title': 'Samurai Champl...
# ...                                                  ...
# 58990                                                 []
# 58991                                                 []
# 58992                                                 []
# 58993                                                 []
# 58994                                                 []
#
#                                      studios  \
# 0            [{'id': 14, 'name': 'Sunrise'}]
# 1            [{'id': 14, 'name': 'Sunrise'}]
# 2            [{'id': 14, 'name': 'Sunrise'}]
# 3            [{'id': 14, 'name': 'Sunrise'}]
# 4            [{'id': 14, 'name': 'Sunrise'}]
# ...                                      ...
# 58990                                     []
# 58991  [{'id': 1835, 'name': 'CloverWorks'}]
# 58992   [{'id': 1997, 'name': 'Studio Kai'}]
# 58993   [{'id': 1997, 'name': 'Studio Kai'}]
# 58994                                     []
#
#                                               statistics  message error
# 0      {'status': {'watching': '137020', 'completed':...      NaN   NaN
# 1      {'status': {'watching': '137020', 'completed':...      NaN   NaN
# 2      {'status': {'watching': '137020', 'completed':...      NaN   NaN
# 3      {'status': {'watching': '137020', 'completed':...      NaN   NaN
# 4      {'status': {'watching': '137020', 'completed':...      NaN   NaN
# ...                                                  ...      ...   ...
# 58990  {'status': {'watching': 0, 'completed': 0, 'on...      NaN   NaN
# 58991  {'status': {'watching': '5', 'completed': '66'...      NaN   NaN
# 58992  {'status': {'watching': 0, 'completed': 0, 'on...      NaN   NaN
# 58993  {'status': {'watching': 0, 'completed': 0, 'on...      NaN   NaN
# 58994  {'status': {'watching': 0, 'completed': 0, 'on...      NaN   NaN
#
# [58995 rows x 33 columns]

# %%
df1[['id', 'genres']]
# Out:
#             id                               genres
# 0          1.0          {'id': 1, 'name': 'Action'}
# 1          1.0       {'id': 2, 'name': 'Adventure'}
# 2          1.0          {'id': 4, 'name': 'Comedy'}
# 3          1.0           {'id': 8, 'name': 'Drama'}
# 4          1.0         {'id': 24, 'name': 'Sci-Fi'}
# ...        ...                                  ...
# 58990  50216.0          {'id': 19, 'name': 'Music'}
# 58991  50218.0         {'id': 24, 'name': 'Sci-Fi'}
# 58992  50221.0          {'id': 19, 'name': 'Music'}
# 58993  50221.0  {'id': 36, 'name': 'Slice of Life'}
# 58994  50227.0          {'id': 19, 'name': 'Music'}
#
# [58995 rows x 2 columns]

# %%
# def melt_series(s):
#     # print(s)
#     lengths = s.str.len().values
#     print((lengths >= 0))
#     # print(lengths)
#     # print(s.values.tolist())
#     flat = [i for i in itertools.chain.from_iterable([s.values.tolist()])]
#     # print("--------------")
#     # print(flat)
#     # print("--------------")
#     lengths1 = lengths.astype(int)
#     print(s.index.values)
#     lengths1[lengths1 < 0] = 0
#     idx = np.repeat(s.index.values, lengths1)
#     print(idx)
#     return pd.Series(flat, idx, name=s.name)


# melt_series(df['genres']).to_frame().join(df.drop('genres', 1)).reindex_axis(df.columns, 1)
